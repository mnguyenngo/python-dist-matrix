# %% [markdown]
# # References
# 1. Scipy Stats Docs

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as scs

plt.style.use('ggplot')

# %% [markdown]
# # Discrete Distributions

# %% [markdown]
# ## Bernoulli

# %%
bern_dist = scs.bernoulli(p=0.5)

# %%
bern_dist_sample = scs.bernoulli.rvs(p=0.5, loc=0, size=10)
bern_dist_sample
# Out:
# array([1, 0, 0, 1, 0, 0, 0, 1, 1, 1])

# %%
bern_dist.mean(), bern_dist.var()
# Out:
# (0.5, 0.25)

# %%
bern_dist.pmf(0), bern_dist.pmf(1)
# Out:
# (0.5, 0.5)

# %%
n = 1
x_points = np.linspace(0,n,2)
fig = plt.figure(figsize = (12,6))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

ax1.set_title("PMF")
ax2.set_title("CDF")

ax1.plot(x_points, bern_dist.pmf(x_points))
ax2.plot(x_points, bern_dist.cdf(x_points))

# %%
bern_dist.cdf(x=0.75)
# Out:
# 0.5

# %% [markdown]
# ## Binomial

# %%
binom_dist = scs.binom(n=50, p=0.5)

# %%
binom_dist.mean(), binom_dist.var()
# Out:
# (25.0, 12.5)

# %%
binom_dist.pmf(k=20), binom_dist.pmf(k=25)
# Out:
# (0.041859149252551922, 0.11227517265921609)

# %%
binom_dist_sample = scs.binom.rvs(n=50, p=0.5, loc=0, size=20)
binom_dist_sample
# Out:
# array([28, 27, 26, 20, 18, 23, 24, 26, 28, 33, 24, 25, 24, 29, 30, 27, 22,
#        16, 33, 26])

# %%
binom_dist.rvs(size=30)
# Out:
# array([21, 26, 28, 27, 26, 15, 27, 22, 31, 23, 32, 26, 26, 23, 24, 23, 19,
#        30, 31, 29, 19, 26, 23, 22, 24, 29, 23, 22, 22, 26])

# %%
n = 50
x_points = np.linspace(0,n,n+1)
fig = plt.figure(figsize = (12,6))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

ax1.set_title("PMF")
ax2.set_title("CDF")

ax1.plot(x_points, binom_dist.pmf(x_points))
ax2.plot(x_points, binom_dist.cdf(x_points))

# %%
binom_dist.cdf(x=25)
# Out:
# 0.55613758632960875

# %% [markdown]
# ## Poisson

# %%
pois_dist = scs.poisson(mu=3, loc=0)

# %%
pois_sample = scs.poisson.rvs(mu=3, loc=0, size=20)
pois_sample
# Out:
# array([2, 3, 5, 0, 5, 4, 2, 3, 6, 1, 3, 2, 1, 3, 4, 2, 2, 7, 4, 3])

# %%
pois_dist.mean(), pois_dist.var()
# Out:
# (3.0, 3.0)

# %%
n = 20
x_points = np.linspace(0,n,n+1)
fig = plt.figure(figsize = (12,6))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

ax1.set_title("PMF")
ax2.set_title("CDF")

ax1.plot(x_points, pois_dist.pmf(x_points))
ax2.plot(x_points, pois_dist.cdf(x_points))

# %%
pois_dist.pmf(k=2), pois_dist.cdf(x=2)
# Out:
# (0.22404180765538775, 0.42319008112684364)

# %% [markdown]
# ## Geometric

# %%
geom_dist = scs.geom(p=0.25, loc=0)

# %%
geom_sample = scs.geom.rvs(p=0.25, loc=0, size=20)
geom_sample
# Out:
# array([ 8,  4,  2,  4,  5,  1,  7, 16,  3,  4,  1,  4,  1,  1,  1,  4,  5,
#        25,  2,  1])

# %%
geom_dist.mean(), geom_dist.var()
# Out:
# (4.0, 12.0)

# %%
n = 10
x_points = np.linspace(1,n,n)
fig = plt.figure(figsize = (12,6))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

ax1.set_title("PMF")
ax2.set_title("CDF")

ax1.plot(x_points, geom_dist.pmf(x_points))
ax2.plot(x_points, geom_dist.cdf(x_points))

# %%
geom_dist.pmf(k=4), geom_dist.cdf(x=4)
# Out:
# (0.10546875, 0.68359375)

# %% [markdown]
# # Continuous Distributions

# %% [markdown]
# ## Normal

# %%
norm_dist = scs.norm(loc=0, scale=2)

# %%
norm_dist = scs.norm

# %%
norm_sample = scs.norm.rvs(loc=0, scale=1, size=20)
norm_sample
# Out:
# array([ 0.67433269, -0.70577469,  0.21360847, -0.21493537,  0.64089738,
#        -1.19173213, -0.05625248,  0.38960014,  1.20167046,  0.20821698,
#        -0.58405389, -0.34145862,  1.41609306, -0.2378359 ,  0.14781817,
#         0.37981926,  0.44978019,  1.30962465, -0.28234439,  1.26767126])

# %%
norm_dist.mean(), norm_dist.var()
# Out:
# (0.0, 4.0)

# %%
norm_dist.pdf(x=1), norm_dist.cdf(x=1)
# Out:
# (0.17603266338214976, 0.69146246127401312)

# %%
x_points = np.linspace(-2, 2, 250)
fig = plt.figure(figsize = (12,6))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

ax1.set_title("PDF")
ax2.set_title("CDF")

ax1.plot(x_points, norm_dist.pdf(x_points))
ax2.plot(x_points, norm_dist.cdf(x_points))

# %% [markdown]
# ## Uniform

# %%
unif_dist = scs.uniform(loc=0, scale=10)

# %%
unif_sample = scs.uniform.rvs(loc=0, scale=10, size=20)
unif_sample
# Out:
# array([ 0.24693846,  0.54730594,  8.6068674 ,  5.32296573,  0.39517814,
#         3.9574014 ,  5.27558641,  8.78676959,  7.93414831,  2.75208375,
#         8.62823177,  9.43127498,  1.25593143,  1.6939473 ,  5.4136616 ,
#         4.99575877,  6.87743596,  4.14903401,  4.40807354,  8.11999839])

# %%
unif_dist.mean(), unif_dist.var()
# Out:
# (5.0, 8.3333333333333321)

# %%
x_points = np.linspace(-2, 12, 250)
fig = plt.figure(figsize = (12,6))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

ax1.set_title("PDF")
ax2.set_title("CDF")

ax1.plot(x_points, unif_dist.pdf(x_points))
ax2.plot(x_points, unif_dist.cdf(x_points))

# %%
unif_dist.pdf(x=3), unif_dist.cdf(x=3)
# Out:
# (0.10000000000000001, 0.29999999999999999)

# %% [markdown]
# ## Exponential

# %%
exp_dist = scs.expon(loc=0, scale=2)

# %%
exp_sample = scs.expon.rvs(loc=0, scale=1, size=20)
exp_sample
# Out:
# array([ 1.18627491,  2.60873997,  0.44411096,  0.08318135,  0.16228881,
#         0.19319811,  2.08665101,  2.12359824,  0.22482759,  1.81296379,
#         0.88510881,  0.28505651,  3.12645189,  1.62475963,  0.35869915,
#         0.79229524,  0.29203181,  0.30523426,  0.74782961,  0.45847683])

# %%
exp_dist.mean(), exp_dist.var()
# Out:
# (2.0, 4.0)

# %%
x_points = np.linspace(0, 12, 250)
fig = plt.figure(figsize = (12,6))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

ax1.set_title("PDF")
ax2.set_title("CDF")

ax1.plot(x_points, exp_dist.pdf(x_points))
ax2.plot(x_points, exp_dist.cdf(x_points))

# %%
exp_dist.pdf(x=1), exp_dist.cdf(x=1)
# Out:
# (0.30326532985631671, 0.39346934028736658)

# %% [markdown]
# ## Gamma

# %%
gam_dist = scs.gamma(a=1, loc=0, scale=2)

# %%
gam_sample = scs.gamma.rvs(a=1, loc=0, scale=2, size=20)
gam_sample
# Out:
# array([ 2.23038383,  3.34199459,  0.6379907 ,  2.63007872,  4.28595327,
#         9.49868868,  1.84941262,  0.15429776,  1.45174956,  1.33630422,
#         0.81540096,  7.5068503 ,  4.89445879,  2.19433087,  1.38079887,
#         0.49047817,  0.14649547,  2.5411593 ,  4.29278328,  4.63590088])

# %%
gam_dist.mean(), gam_dist.var()
# Out:
# (2.0, 4.0)

# %%
x_points = np.linspace(0, 12, 250)
fig = plt.figure(figsize = (12,6))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

ax1.set_title("PDF")
ax2.set_title("CDF")

ax1.plot(x_points, gam_dist.pdf(x_points))
ax2.plot(x_points, gam_dist.cdf(x_points))

# %%
gam_dist.pdf(x=3), gam_dist.cdf(x=3)
# Out:
# (0.11156508007421491, 0.77686983985157021)
